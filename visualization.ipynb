# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据
spring_predictions = pd.read_csv("spring_predictions.csv", encoding="GB2312")

# 打印描述统计信息
print(spring_predictions[['真实值', '预测值']].describe())

# 绘制真实值和预测值的直方图
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.hist(spring_predictions['真实值'], bins=50, color='blue', alpha=0.7)
plt.title('真实值分布')
plt.xlabel('真实值')
plt.ylabel('频率')

plt.subplot(1, 2, 2)
plt.hist(spring_predictions['预测值'], bins=50, color='green', alpha=0.7)
plt.title('预测值分布')
plt.xlabel('预测值')
plt.ylabel('频率')

plt.tight_layout()
plt.show()
# Out:
#                 真实值           预测值
# count  1.048575e+06  1.048575e+06
# mean   1.593490e+02  1.909240e+02
# std    1.305868e+02  1.362039e+02
# min    0.000000e+00 -4.696352e+01
# 25%    6.693341e+01  9.212958e+01
# 50%    1.255197e+02  1.611892e+02
# 75%    2.169197e+02  2.587349e+02
# max    1.717954e+03  1.451604e+03
# C:\Users\59223\AppData\Local\Temp\ipykernel_32452\710535984.py:25: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from current font.
#   plt.tight_layout()
# C:\Users\59223\AppData\Local\Temp\ipykernel_32452\710535984.py:25: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from current font.
#   plt.tight_layout()
# C:\Users\59223\AppData\Local\Temp\ipykernel_32452\710535984.py:25: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   plt.tight_layout()
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 读取CSV文件
df = pd.read_csv('fall_predictions.csv')

# 绘制散点图
plt.figure(figsize=(8, 6))

# 设置渐变色
colors = np.linspace(0, 1, len(df))
plt.scatter(df['预测值'], df['真实值'], c=colors, cmap='viridis_r', alpha=0.5, s=1)

plt.title('Scatter Plot of Real vs Predicted Values')
plt.xlabel('Predicted Values')
plt.ylabel('Real Values')

# 添加斜线
plt.plot([0, 5000], [0, 5000], linestyle='--', color='black')

# 设置纵坐标范围和间隔
plt.ylim(0, 5000)
plt.yticks(range(0, 5001, 500))

# 设置横坐标范围和间隔
plt.xlim(0, 5000)
plt.xticks(range(0, 5001, 500))

# 去除最上面和最右边的线
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# 设置网格线
plt.grid(True)

# 保存图片到本地
plt.savefig('scatter_plot_fall.png', dpi=300)

plt.show()
